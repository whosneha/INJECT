# %% [markdown]
# # Tutorial: Injecting Star Clusters into Rubin Images
#
# This notebook demonstrates a simple injection workflow and uses the local package when available.

# %%
import os
import sys

repo_root = os.getcwd()
for candidate in [
    repo_root,
    os.path.abspath(os.path.join(repo_root, '..')),
    os.path.abspath(os.path.join(repo_root, 'star-cluster-injection-pipeline')),
    os.path.abspath(os.path.join(repo_root, '..', 'star-cluster-injection-pipeline')),
    os.path.expanduser('~/INJECT/star-cluster-injection-pipeline'),
    os.path.expanduser('~/WORK/INJECT/star-cluster-injection-pipeline'),
]:
    if os.path.exists(os.path.join(candidate, 'pyproject.toml')) and os.path.exists(os.path.join(candidate, 'src')):
        sys.path.insert(0, candidate)
        break
